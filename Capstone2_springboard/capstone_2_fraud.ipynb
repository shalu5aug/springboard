# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('Train-1542865627584.csv')

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
outpatient= pd.read_csv("Train_Outpatientdata-1542865627584.csv")

# %%
inpatient= pd.read_csv("Train_Inpatientdata-1542865627584.csv")

# %%
beneficiary= pd.read_csv("Train_Beneficiarydata-1542865627584.csv")

# %%
beneficiary.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
# ...

# %%
pd.set_option('display.max_columns',30)
outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
df_procedure_in = pd.DataFrame(columns=['procedure1'])

# %%
df_procedure_in
# Out:
# Empty DataFrame
# Columns: [procedure1]
# Index: []

# %%
df_procedure_in['procedure1'] = pd.concat([inpatient['ClmProcedureCode_1'],inpatient['ClmProcedureCode_2'],
                             inpatient['ClmProcedureCode_3'],inpatient['ClmProcedureCode_4'],inpatient['ClmProcedureCode_5'],inpatient['ClmProcedureCode_6']], axis=0).dropna()

# %%
grouped_procedure_in = df_procedure_in.value_counts()
grouped_procedure_in = grouped_procedure_in.to_frame()

# %%
grouped_procedure_in
# Out:
#       procedure1  count  percentage
# 0         4019.0   1953    6.577529
# 1         9904.0   1137    3.829314
# 2         2724.0   1047    3.526202
# 3         8154.0   1021    3.438637
# 4           66.0    894    3.010912
# ...          ...    ...         ...
# 1319      4468.0      1    0.003368
# 1127      5717.0      1    0.003368
# 1311      4431.0      1    0.003368
# 1299      4040.0      1    0.003368
# 1320        11.0      1    0.003368
#
# [1321 rows x 3 columns]

# %%
grouped_procedure_in.columns= ['count']

# %%
grouped_procedure_in = grouped_procedure_in.reset_index()

# %%
grouped_procedure_in.rename(columns={0:'count'})
# Out:
#       procedure1  count
# 0         4019.0   1953
# 1         9904.0   1137
# 2         2724.0   1047
# 3         8154.0   1021
# 4           66.0    894
# ...          ...    ...
# 1316      8204.0      1
# 1317      4444.0      1
# 1318      4461.0      1
# 1319      4468.0      1
# 1320        11.0      1
#
# [1321 rows x 2 columns]

# %%
grouped_procedure_in['percentage'] = (grouped_procedure_in['count']/sum(grouped_procedure_in['count']))*100

# %%
grouped_procedure_in
# Out:
#       procedure1  count  percentage
# 0         4019.0   1953    6.577529
# 1         9904.0   1137    3.829314
# 2         2724.0   1047    3.526202
# 3         8154.0   1021    3.438637
# 4           66.0    894    3.010912
# ...          ...    ...         ...
# 1316      8204.0      1    0.003368
# 1317      4444.0      1    0.003368
# 1318      4461.0      1    0.003368
# 1319      4468.0      1    0.003368
# 1320        11.0      1    0.003368
#
# [1321 rows x 3 columns]

# %%
grouped_procedure_in.sort_values(by='percentage', ascending=False, inplace=True)

# %%
grouped_procedure_in.head(20).plot(x='procedure1', y='percentage', kind='bar',figsize=(12,6), title='procedure inpatient')
# Out:
# <AxesSubplot:title={'center':'procedure inpatient'}, xlabel='procedure1'>

# %% [markdown]
# ### df_procedure_out = pd.DataFrame(columns=['procedure1'])

# %%
df_procedure_out['procedure1'] = pd.concat([outpatient['ClmProcedureCode_1'],outpatient['ClmProcedureCode_2'],
                             outpatient['ClmProcedureCode_3'],outpatient['ClmProcedureCode_4'],outpatient['ClmProcedureCode_5'],outpatient['ClmProcedureCode_6']],axis=0).dropna()

# %%
grouped_procedure_out = df_procedure_out.value_counts()
grouped_procedure_out = grouped_procedure_out.to_frame()

# %%
grouped_procedure_out.columns=['count']

# %%
grouped_procedure_out = grouped_procedure_out.reset_index()

# %%
grouped_procedure_out['percentage'] = (grouped_procedure_out['count']/sum(grouped_procedure_out['count']))*100

# %%
grouped_procedure_out.sort_values(by='percentage', ascending=False, inplace=True)

# %%
grouped_procedure_out.head(20).plot(x='procedure1', y='percentage', kind='bar', figsize=(12,6), title='procedure outpatient')
# Out:
# <AxesSubplot:title={'center':'procedure outpatient'}, xlabel='procedure1'>

# %%
procedure_in_out = pd.concat(axis=)

# %%
df_diagnosis_in = pd.DataFrame(columns=['diagnosis'])

# %%
df_diagnosis_in
# Out:
# Empty DataFrame
# Columns: [diagnosis]
# Index: []

# %%
df_diagnosis_in = pd.concat([inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_2'],inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_1'],
                            inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_1'],inpatient['ClmDiagnosisCode_1'],
                            inpatient['ClmDiagnosisCode_1']], axis=0).dropna()

# %%
df_diagnosis_in.value_counts()
# Out:
# 486      13773
# 41401    10598
# V5789    10423
# 49121     8920
# 0389      8570
#          ...
# 71230        1
# 9597         1
# 8362         1
# 79402        1
# 34291        1
# Length: 3364, dtype: int64

# %%
grouped_diag_in = df_diagnosis_in.value_counts()
grouped_diag_in = grouped_diag_in.to_frame()
grouped_diag_in.columns = ['count']

# %%
grouped_diag_in['diagnosis'] = grouped_diag_in.index

# %%
grouped_diag_in['percentage'] = (grouped_diag_in['count']/sum(grouped_diag_in['count']))*100

# %%
grouped_diag_in.sort_values(by='percentage', ascending=False, inplace=True)

# %%
grouped_diag_in.head(20).plot(x='diagnosis', y='percentage', kind='bar', figsize=(12,6), title='Diagnosis Inpatient')
# Out:
# <AxesSubplot:title={'center':'Diagnosis Inpatient'}, xlabel='diagnosis'>

# %%
df_diagnosis_out = pd.DataFrame(columns=['diagnosis'])

# %%
df_diagnosis_out = pd.concat([outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_2'],outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_1'],
                            outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_1'],outpatient['ClmDiagnosisCode_1'],
                            outpatient['ClmDiagnosisCode_1']], axis=0).dropna()

# %%
grouped_diag_out = df_diagnosis_out.value_counts()
grouped_diag_out = grouped_diag_out.to_frame()

# %%
grouped_diag_out.columns = ['count']

# %%
grouped_diag_out['diagnosis'] = grouped_diag_out.index

# %%
grouped_diag_out['perc'] = (grouped_diag_out['count']/sum(grouped_diag_out['count']))*100

# %%
grouped_diag_out.sort_values(by='perc', ascending=False, inplace=True)

# %%
grouped_diag_out['diagnosis'] = grouped_diag_out['diagnosis'].astype(str)

grouped_diag_out.head(20).plot(x='diagnosis', y='perc', kind='bar', figsize=(12,6), title='Diagnosis Outpatient')
# Out:
# <AxesSubplot:title={'center':'Diagnosis Outpatient'}, xlabel='diagnosis'>

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
t_df = train['PotentialFraud'].value_counts()
t_df = t_df.to_frame()
t_df.columns = ['count']

# %%
t_df['fraud'] = t_df.index

# %%
t_df
# Out:
#      count fraud
# No    4904    No
# Yes    506   Yes

# %%
t_df.plot(x='fraud', y='count', kind='bar')
# Out:
# <AxesSubplot:xlabel='fraud'>

# %%
outpatient.shape
# Out:
# (517737, 27)

# %%
flt_yes = train['PotentialFraud']=='Yes'
train_yes = train.loc[flt_yes]

# %%
train_yes
# Out:
#       Provider PotentialFraud
# 1     PRV51003            Yes
# 3     PRV51005            Yes
# 13    PRV51021            Yes
# 25    PRV51037            Yes
# 37    PRV51052            Yes
# ...        ...            ...
# 5307  PRV57642            Yes
# 5324  PRV57667            Yes
# 5329  PRV57672            Yes
# 5351  PRV57697            Yes
# 5360  PRV57709            Yes
#
# [506 rows x 2 columns]

# %%
#which are the most codes used by fraud providers

# %%
potential_fraud_out = pd.merge(train_yes,outpatient, how='inner', on='Provider')

# %%
potential_fraud_out
# Out:
#         Provider PotentialFraud      BeneID    ClaimID ClaimStartDt  \
# 0       PRV51003            Yes   BENE11305  CLM374220   2009-05-23
# 1       PRV51003            Yes   BENE12706  CLM220170   2009-02-28
# 2       PRV51003            Yes   BENE16670  CLM524110   2009-08-14
# 3       PRV51003            Yes   BENE17227  CLM176030   2009-02-04
# 4       PRV51003            Yes   BENE17385  CLM252553   2009-03-18
# ...          ...            ...         ...        ...          ...
# 189389  PRV57709            Yes  BENE153075  CLM265386   2009-03-24
# 189390  PRV57709            Yes  BENE155248  CLM499034   2009-07-30
# 189391  PRV57709            Yes  BENE157268  CLM479379   2009-07-19
# 189392  PRV57709            Yes  BENE157340  CLM378711   2009-05-25
# 189393  PRV57709            Yes  BENE157975  CLM521381   2009-08-12
#
#         ClaimEndDt  InscClaimAmtReimbursed AttendingPhysician  \
# 0       2009-06-12                    2400          PHY327121
# ...

# %%
(len(potential_fraud_out)/len(outpatient))*100
# Out:
# 36.58112130290089

# %%
potential_fraud_in = pd.merge(train_yes,inpatient, how='inner', on='Provider')

# %%
potential_fraud_in
# Out:
#        Provider PotentialFraud      BeneID   ClaimID ClaimStartDt  ClaimEndDt  \
# 0      PRV51003            Yes   BENE18650  CLM50983   2009-05-13  2009-05-19
# 1      PRV51003            Yes   BENE21377  CLM40101   2009-02-26  2009-03-05
# 2      PRV51003            Yes   BENE24383  CLM46423   2009-04-10  2009-04-16
# 3      PRV51003            Yes   BENE25685  CLM75439   2009-11-11  2009-11-18
# 4      PRV51003            Yes   BENE30002  CLM39293   2009-02-20  2009-02-23
# ...         ...            ...         ...       ...          ...         ...
# 23397  PRV57709            Yes  BENE110195  CLM50559   2009-05-10  2009-05-12
# 23398  PRV57709            Yes  BENE124354  CLM79935   2009-12-17  2009-12-20
# 23399  PRV57709            Yes  BENE136192  CLM48501   2009-04-25  2009-04-27
# 23400  PRV57709            Yes  BENE150484  CLM47810   2009-04-20  2009-04-24
# 23401  PRV57709            Yes  BENE155681  CLM76173   2009-11-16  2009-11-20
#
# ...

# %%
(len(potential_fraud_in)/len(inpatient)) *100
# Out:
# 57.81983495577408

# %%
#procedure codes used by Frauds in Inpatient

# %%
df_proc_fraud_in = pd.DataFrame(['procedure'])

# %%
df_proc_fraud_in = pd.concat([potential_fraud_in['ClmProcedureCode_1'],potential_fraud_in['ClmProcedureCode_2'],
                            potential_fraud_in['ClmProcedureCode_3'],potential_fraud_in['ClmProcedureCode_4'],
                            potential_fraud_in['ClmProcedureCode_5'],potential_fraud_in['ClmProcedureCode_6']], axis=0).dropna()

# %%
df_proc_fraud_in = df_proc_fraud_in.value_counts()
df_proc_fraud_in = df_proc_fraud_in.to_frame()

# %%
type(df_proc_fraud_in)
# Out:
# pandas.core.frame.DataFrame

# %%
df_proc_fraud_in['procedure'] = df_proc_fraud_in.index

# %%
df_proc_fraud_in.columns
# Out:
# Index([0, 'procedure'], dtype='object')

# %%
df_proc_fraud_in = df_proc_fraud_in.rename(columns={0:'count'})

# %%
df_proc_fraud_in['percentage'] = (df_proc_fraud_in['count']/sum(df_proc_fraud_in['count']))*100

# %%
df_proc_fraud_in.head(10)
# Out:
#         count  procedure  percentage
# 4019.0   1137     4019.0    6.562771
# 2724.0    641     2724.0    3.699856
# 9904.0    629     9904.0    3.630592
# 8154.0    614     8154.0    3.544012
# 66.0      535       66.0    3.088023
# 3893.0    483     3893.0    2.787879
# 3995.0    474     3995.0    2.735931
# 4516.0    365     4516.0    2.106782
# 3722.0    332     3722.0    1.916306
# 8151.0    280     8151.0    1.616162

# %%
df_proc_fraud_in.head(10).plot(kind='bar', x='procedure', y='percentage', figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='procedure'>

# %%
#diagnosis codes used by inpatient

# %%
df_diag_fraud_in = pd.DataFrame(['procedure'])

# %%
df_diag_fraud_in = pd.concat([potential_fraud_in['ClmDiagnosisCode_1'],potential_fraud_in['ClmDiagnosisCode_2'],
                            potential_fraud_in['ClmDiagnosisCode_3'],potential_fraud_in['ClmDiagnosisCode_4'],
                            potential_fraud_in['ClmDiagnosisCode_5'],potential_fraud_in['ClmDiagnosisCode_6'],
                            potential_fraud_in['ClmDiagnosisCode_7'],potential_fraud_in['ClmDiagnosisCode_8'],
                            potential_fraud_in['ClmDiagnosisCode_9'],potential_fraud_in['ClmDiagnosisCode_10']], axis=0)

# %%
df_in_diag = df_diag_fraud_in.value_counts()
# df_diag_fraud_in = df_diag_fraud_in.to_frame()
df_in_diag = df_in_diag.to_frame()
df_in_diag['diagnosis'] = df_in_diag.index
df_in_diag.rename(columns={0:'count'}, inplace=True)
df_in_diag['percentage'] = (df_in_diag['count']/sum(df_in_diag['count']))*100

# %%
df_in_diag
# Out:
#        count diagnosis  percentage
# 4019    8116      4019    4.286718
# 25000   4248     25000    2.243713
# 2724    4245      2724    2.242129
# 41401   3744     41401    1.977510
# 4280    3585      4280    1.893529
# ...      ...       ...         ...
# 1140       1      1140    0.000528
# 75615      1     75615    0.000528
# 84510      1     84510    0.000528
# 7383       1      7383    0.000528
# 9059       1      9059    0.000528
#
# [4167 rows x 3 columns]

# %%
df_in_diag.head(10).plot(kind='bar', x='diagnosis', y='percentage', figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='diagnosis'>

# %%
#codes used by frauds in outpatient

# %%
df_proc_fraud_out = pd.DataFrame(['procedure'])

# %%
df_proc_fraud_out = pd.concat([potential_fraud_out['ClmProcedureCode_1'],potential_fraud_out['ClmProcedureCode_2'],
                            potential_fraud_out['ClmProcedureCode_3'],potential_fraud_out['ClmProcedureCode_4'],
                            potential_fraud_out['ClmProcedureCode_5'],potential_fraud_out['ClmProcedureCode_6']], axis=0).dropna()

# %%
df_proc_fraud_out = df_proc_fraud_out.value_counts()
df_proc_fraud_out = df_proc_fraud_out.to_frame()

# %%
df_proc_fraud_out['procedure'] = df_proc_fraud_out.index

# %%
df_proc_fraud_out.rename(columns={0:'count'}, inplace=True)

# %%
df_proc_fraud_out['percentage'] = (df_proc_fraud_out['count']/sum(df_proc_fraud_out['count']))*100

# %%
df_proc_fraud_out.head(10)
# Out:
#         count  procedure  percentage
# 9904.0      5     9904.0    5.555556
# 4516.0      5     4516.0    5.555556
# 66.0        4       66.0    4.444444
# 9952.0      3     9952.0    3.333333
# 5123.0      3     5123.0    3.333333
# 9390.0      3     9390.0    3.333333
# 8703.0      3     8703.0    3.333333
# 3995.0      3     3995.0    3.333333
# 5849.0      2     5849.0    2.222222
# 1741.0      2     1741.0    2.222222

# %%
df_proc_fraud_out.head(10).plot(kind='bar', x='procedure', y='percentage', figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='procedure'>

# %%
#diagnostic code used by fraud in outpatient

# %%
df_diag_fraud_out = pd.DataFrame(['procedure'])

# %%
df_diag_fraud_out = pd.concat([potential_fraud_out['ClmDiagnosisCode_1'],potential_fraud_out['ClmDiagnosisCode_2'],
                            potential_fraud_out['ClmDiagnosisCode_3'],potential_fraud_out['ClmDiagnosisCode_4'],
                            potential_fraud_out['ClmDiagnosisCode_5'],potential_fraud_out['ClmDiagnosisCode_6'],
                            potential_fraud_out['ClmDiagnosisCode_7'],potential_fraud_out['ClmDiagnosisCode_8'],
                            potential_fraud_out['ClmDiagnosisCode_9'],potential_fraud_out['ClmDiagnosisCode_10']], axis=0)

# %%
df_out_diag = df_diag_fraud_out.value_counts()
# df_diag_fraud_in = df_diag_fraud_in.to_frame()
df_out_diag = df_out_diag.to_frame()
df_out_diag['diagnosis'] = df_out_diag.index
df_out_diag.rename(columns={0:'count'}, inplace=True)
df_out_diag['percentage'] = (df_out_diag['count']/sum(df_out_diag['count']))*100

# %%
df_out_diag
# Out:
#        count diagnosis  percentage
# 4019   22913      4019    4.630114
# 25000  10839     25000    2.190277
# 2724   10445      2724    2.110660
# V5869   8809     V5869    1.780067
# 4011    8512      4011    1.720051
# ...      ...       ...         ...
# 0787       1      0787    0.000202
# 9795       1      9795    0.000202
# 75617      1     75617    0.000202
# 64272      1     64272    0.000202
# 64724      1     64724    0.000202
#
# [9523 rows x 3 columns]

# %%
df_out_diag.head(10).plot(kind='bar', x='diagnosis', y='percentage', figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='diagnosis'>

# %%
# inpatient.head()

# %%
potential_fraud_in
# Out:
#        Provider PotentialFraud      BeneID   ClaimID ClaimStartDt  ClaimEndDt  \
# 0      PRV51003            Yes   BENE18650  CLM50983   2009-05-13  2009-05-19
# 1      PRV51003            Yes   BENE21377  CLM40101   2009-02-26  2009-03-05
# 2      PRV51003            Yes   BENE24383  CLM46423   2009-04-10  2009-04-16
# 3      PRV51003            Yes   BENE25685  CLM75439   2009-11-11  2009-11-18
# 4      PRV51003            Yes   BENE30002  CLM39293   2009-02-20  2009-02-23
# ...         ...            ...         ...       ...          ...         ...
# 23397  PRV57709            Yes  BENE110195  CLM50559   2009-05-10  2009-05-12
# 23398  PRV57709            Yes  BENE124354  CLM79935   2009-12-17  2009-12-20
# 23399  PRV57709            Yes  BENE136192  CLM48501   2009-04-25  2009-04-27
# 23400  PRV57709            Yes  BENE150484  CLM47810   2009-04-20  2009-04-24
# 23401  PRV57709            Yes  BENE155681  CLM76173   2009-11-16  2009-11-20
#
# ...

# %%
# beneficiary.head()

# %%
fraud_beneficiary_ip_op_df = pd.merge(beneficiary, potential_fraud_in, how='inner', on='BeneID')
fraud_beneficiary_ip_op_df.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11017  1940-06-01  NaN       2     1                     0     31
# 2  BENE11028  1941-12-01  NaN       1     1                     0     38
# 3  BENE11034  1946-03-01  NaN       2     1                     0     34
# 4  BENE11034  1946-03-01  NaN       2     1                     0     34
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     270                   12                   12                      1
# 2     230                   12                   12                      2
# 3     760                   12                   12                      1
# 4     760                   12                   12                      1
#
# ...

# %%
Train_F_Beneficiary_grouped = fraud_beneficiary_ip_op_df['State'].value_counts()
Train_F_Beneficiary_grouped.head()
# Out:
# 5     1986
# 10    1909
# 33    1706
# 45    1401
# 36    1223
# Name: State, dtype: int64

# %%
Train_F_Beneficiary_grouped1 = Train_F_Beneficiary_grouped.to_frame()
Train_F_Beneficiary_grouped1['Count'] =  Train_F_Beneficiary_grouped1['State']
Train_F_Beneficiary_grouped1['STATE'] = Train_F_Beneficiary_grouped1.index
Train_F_Beneficiary_grouped1 = Train_F_Beneficiary_grouped1.drop(['State'], axis = 1)
Train_F_Beneficiary_grouped1 = Train_F_Beneficiary_grouped1.head(20)
Train_F_Beneficiary_grouped1
# Out:
#     Count  STATE
# 5    1986      5
# 10   1909     10
# 33   1706     33
# 45   1401     45
# 36   1223     36
# 14    998     14
# 34    924     34
# 39    852     39
# 31    745     31
# 49    702     49
# 22    626     22
# 21    621     21
# 23    614     23
# 15    604     15
# 11    583     11
# 44    562     44
# 26    506     26
# 3     494      3
# 7     479      7
# 52    430     52

# %%
Train_F_Beneficiary_grouped1.plot(x ='STATE', y='Count', kind = 'bar', figsize= (12,6));

# %%
#add age column to benefeciary

# %%
fraud_beneficiary_ip_op_df.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11017  1940-06-01  NaN       2     1                     0     31
# 2  BENE11028  1941-12-01  NaN       1     1                     0     38
# 3  BENE11034  1946-03-01  NaN       2     1                     0     34
# 4  BENE11034  1946-03-01  NaN       2     1                     0     34
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     270                   12                   12                      1
# 2     230                   12                   12                      2
# 3     760                   12                   12                      1
# 4     760                   12                   12                      1
#
# ...

# %%
#Average Age for the data set and as a comparison for the probable fradulent activites applied on what age range

# %%
now = pd.to_datetime('2019-12-01', format='%Y-%m-%d')
fraud_beneficiary_ip_op_df['DOB'] = pd.to_datetime(fraud_beneficiary_ip_op_df['DOB'] , format='%Y-%m-%d')
fraud_beneficiary_ip_op_df['age'] = pd.Series([(now - date) for date in fraud_beneficiary_ip_op_df['DOB'] if date < now])
fraud_beneficiary_ip_op_df['age'] = fraud_beneficiary_ip_op_df['age'].astype('<m8[Y]')

# %%
fraud_beneficiary_ip_op_df['age'].plot.hist(bins=20, figsize=(12,6), alpha=0.5, edgecolor='b')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Average Age for the data set in beneficiary

# %%
beneficiary['DOB'] =  pd.to_datetime(beneficiary['DOB'], format='%Y-%m-%d')  
now = pd.to_datetime('2009-12-01' , format = '%Y-%m-%d') # Assuming this is 2009 data as the last recorded death is for 2009
beneficiary['DOB'] = beneficiary['DOB'].where(beneficiary['DOB'] < now)
beneficiary['age'] = (now - beneficiary['DOB']).astype('<m8[Y]')
ax = beneficiary['age'].plot.hist(bins=20, alpha=0.5, figsize=(8, 6), edgecolor='b')

# %%
#What is the average cost of potential fraud claims and also what is the cost as % of whole. Checking the outliers for such claims

# %%
ax = inpatient['InscClaimAmtReimbursed'].plot.hist(bins=20, alpha=0.5, figsize=(8, 6), facecolor='g', edgecolor='g')

# %%
# train

# %%
# import seaborn as sns
# inpatient_1 = pd.merge(inpatient, train, on='Provider', how='inner')
# g = sns.FacetGrid(inpatient_1, col='PotentialFraud', height=6)
# g.map(plt.hist,  'InscClaimAmtReimbursed', )

# %%
import seaborn as sns
inpatient_1 = pd.merge(inpatient, train, how='inner', on='Provider')
g = sns.FacetGrid(inpatient_1, col='PotentialFraud', height=6)
g.map(plt.hist, 'InscClaimAmtReimbursed', bins=20, color = 'g')

# %%
#We see that it is a significantly large amount which might be fradulent.

# %%
inpatient_1 = inpatient_1.loc[(inpatient_1['PotentialFraud'] == 'Yes')]
Total = inpatient_1['InscClaimAmtReimbursed'].sum()
print(Total)
# Out:
# 241288510

# %%
#outpatient

# %%
ax = outpatient['InscClaimAmtReimbursed'].plot.hist(bins=100,range=[0,5000], alpha=0.5, figsize=(8, 6), facecolor='c', edgecolor='k')

# %%
outpatient_1 = pd.merge(outpatient, train, how='inner', on='Provider')
g = sns.FacetGrid(outpatient_1, col='PotentialFraud', height=6)
g.map(plt.hist, 'InscClaimAmtReimbursed', bins=20, range=[0, 5000], color ='c')

# %%
#missing values in beneficiary

# %%
beneficiary.isnull().sum()
# Out:
# BeneID                                  0
# DOB                                     0
# DOD                                137135
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# ...

# %%
#adding age column to beneficiary

# %%
beneficiary['DOB'] = pd.to_datetime(beneficiary['DOB'] , format = '%Y-%m-%d')
beneficiary['DOD'] = pd.to_datetime(beneficiary['DOD'],format = '%Y-%m-%d',errors='ignore')
beneficiary['Age1'] = round(((beneficiary['DOD'] - beneficiary['DOB']).dt.days)/365)

# %%
beneficiary.Age1.fillna(round(((pd.to_datetime('2009-12-01' , format = '%Y-%m-%d') - beneficiary['DOB']).dt.days)/365),
                                 inplace=True)

# %%
beneficiary[['age','Age1']]
# Out:
#          age  Age1
# 0       66.0  67.0
# 1       73.0  73.0
# 2       73.0  73.0
# 3       87.0  87.0
# 4       74.0  74.0
# ...      ...   ...
# 138551  70.0  70.0
# 138552  71.0  71.0
# 138553  93.0  94.0
# 138554  79.0  80.0
# 138555  57.0  58.0
#
# [138556 rows x 2 columns]

# %%
## Creating the master DF
inpatient['EncounterType'] = 0
outpatient['EncounterType'] = 1
frames = [inpatient, outpatient]
TrainInAndOut = pd.concat(frames)
TrainInAndOutBenf = pd.merge(TrainInAndOut, beneficiary, how='inner', on='BeneID')
Master_df = pd.merge(TrainInAndOutBenf, train, how='inner', on='Provider')

# %%
Master_df.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06  2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN         NaN                   NaN                0.0
# ...

# %%
Master_df['PotentialFraud'].value_counts()
# Out:
# No     345415
# Yes    212796
# Name: PotentialFraud, dtype: int64

# %%
Master_df.shape
# Out:
# (558211, 58)

# %%
Master_df.isnull().sum()
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1508
# OperatingPhysician                 443764
# OtherPhysician                     358475
# AdmissionDt                        517737
# ClmAdmitDiagnosisCode              412312
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                 517737
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195606
# ClmDiagnosisCode_3                 315156
# ClmDiagnosisCode_4                 393675
# ClmDiagnosisCode_5                 446287
# ClmDiagnosisCode_6                 473819
# ClmDiagnosisCode_7                 492034
# ClmDiagnosisCode_8                 504767
# ...

# %%
flt =Master_df['DOD'].isnull()
Master_df.loc[flt, 'IsDead']='0'
Master_df.loc[~flt, 'IsDead']='1'

# %%
Master_df.drop(['age'], axis=1)
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE16973  CLM565430   2009-09-06  2009-09-06  PRV55912
# 2        BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3        BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4        BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
# ...            ...        ...          ...         ...       ...
# 558206  BENE154147  CLM394122   2009-06-02  2009-06-04  PRV54050
# 558207  BENE154687  CLM184358   2009-02-08  2009-02-08  PRV54302
# 558208  BENE157378  CLM460770   2009-07-09  2009-07-29  PRV51577
# 558209  BENE158295  CLM306999   2009-04-16  2009-04-16  PRV53083
# 558210  BENE158736  CLM589654   2009-09-20  2009-09-20  PRV56377
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
Master_df['AdmissionDt'] = pd.to_datetime(Master_df['AdmissionDt'], format='%Y-%m-%d')

# %%
Master_df['DischargeDt'] = pd.to_datetime(Master_df['DischargeDt'], format='%Y-%m-%d')

# %%
Master_df['daysAdmitted'] = ((Master_df['DischargeDt'] - Master_df['AdmissionDt']).dt.days)+1

# %%
Master_df['daysAdmitted']
# Out:
# 0          7.0
# 1          NaN
# 2         13.0
# 3         19.0
# 4          5.0
#           ...
# 558206     NaN
# 558207     NaN
# 558208     NaN
# 558209     NaN
# 558210     NaN
# Name: daysAdmitted, Length: 558211, dtype: float64

# %%
## removing the column DOD and DOB also creating a new column IsDead as we already 
#have the age we do not need date of death and date of birth

# %%
Master_df = Master_df.drop(['DOD'], axis = 1)
Master_df = Master_df.drop(['DOB'], axis = 1)

# %%
Master_df.loc[Master_df['EncounterType']==1, 'daysAdmitted'] = 0

# %%
Master_df.rename(columns={'daysAdmitted':'DaysAdmitted'}, inplace=True)

# %%
Master_df['DaysAdmitted']
# Out:
# 0          7.0
# 1          0.0
# 2         13.0
# 3         19.0
# 4          5.0
#           ...
# 558206     0.0
# 558207     0.0
# 558208     0.0
# 558209     0.0
# 558210     0.0
# Name: DaysAdmitted, Length: 558211, dtype: float64

# %%
Master_df = Master_df.drop(['DischargeDt'], axis = 1)
Master_df = Master_df.drop(['AdmissionDt'], axis = 1)

# %%
Master_df.loc[Master_df['DeductibleAmtPaid'].isnull(), 'DeductibleAmtPaid'] = '0'

# %%
#replace null procedures and diagnosis code with '0'

# %%
cols= ['ClmAdmitDiagnosisCode', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_10',
       'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4',
       'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7',
       'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6']

# %%
# Master_df.replace[cols]
Master_df[cols]= Master_df[cols].replace({np.nan:0})
# Master_df[cols].replace({np.nan:0})
Master_df
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE16973  CLM565430   2009-09-06  2009-09-06  PRV55912
# 2        BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3        BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4        BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
# ...            ...        ...          ...         ...       ...
# 558206  BENE154147  CLM394122   2009-06-02  2009-06-04  PRV54050
# 558207  BENE154687  CLM184358   2009-02-08  2009-02-08  PRV54302
# 558208  BENE157378  CLM460770   2009-07-09  2009-07-29  PRV51577
# 558209  BENE158295  CLM306999   2009-04-16  2009-04-16  PRV53083
# 558210  BENE158736  CLM589654   2009-09-20  2009-09-20  PRV56377
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
# for i in cols:
#     Master_df[i][Master_df[i]!=0]=1
# Master_df['ClmDiagnosisCode_2'][Master_df['ClmDiagnosisCode_3']=='5853']
# Out:
# Series([], Name: ClmDiagnosisCode_2, dtype: float64)

# %%
for i in cols:
    Master_df[i][Master_df[i]!=0]= 1
# Out:
# <ipython-input-589-e1a5aca44231>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Master_df[i][Master_df[i]!=0]= 1
# <ipython-input-589-e1a5aca44231>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Master_df[i][Master_df[i]!=0]= 1
# <ipython-input-589-e1a5aca44231>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Master_df[i][Master_df[i]!=0]= 1
# <ipython-input-589-e1a5aca44231>:2: SettingWithCopyWarning:
# ...

# %%
Master_df[cols]= Master_df[cols].astype(float)

# %%
#refill null Deductible Amt
Master_df.loc[Master_df['DeductibleAmtPaid'].isnull(), 'DeductibleAmtPaid'] = '0'

# %%
Master_df['TotalDiagnosis']= Master_df['ClmDiagnosisCode_1']+Master_df['ClmDiagnosisCode_10']+Master_df['ClmDiagnosisCode_2']+ Master_df['ClmDiagnosisCode_3']+ Master_df['ClmDiagnosisCode_4']+Master_df['ClmDiagnosisCode_5']+ Master_df['ClmDiagnosisCode_6']+ Master_df['ClmDiagnosisCode_7']+Master_df['ClmDiagnosisCode_8']+ Master_df['ClmDiagnosisCode_9']

# %%
Master_df['TotalProcedure']= Master_df['ClmProcedureCode_1']+Master_df['ClmProcedureCode_2']+Master_df['ClmProcedureCode_3']+ Master_df['ClmProcedureCode_4']+ Master_df['ClmProcedureCode_5']+Master_df['ClmProcedureCode_6']

# %%
Master_df.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid',
#        'DiagnosisGroupCode', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'EncounterType', 'DOB',
#        'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'NoOfMonths_PartACov', 'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
#remove unnecessary columns

# %%
remove=['Provider','BeneID', 'ClaimID', 'ClaimStartDt','ClaimEndDt','AttendingPhysician',
       'OperatingPhysician', 'OtherPhysician', 'ClmDiagnosisCode_1',
       'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4',
       'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7',
       'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10',
       'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3',
       'ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6',
       'ClmAdmitDiagnosisCode','DeductibleAmtPaid','NoOfMonths_PartACov',
        'NoOfMonths_PartBCov','DiagnosisGroupCode',
        'State', 'County']

# %%
Master_df.drop(columns=remove, axis=1, inplace=True)

# %%
Master_df.head()
# Out:
#    InscClaimAmtReimbursed  EncounterType  Gender  Race RenalDiseaseIndicator  \
# 0                   26000              0       1     1                     0
# 1                      50              1       1     1                     0
# 2                   19000              0       2     1                     0
# 3                   17000              0       1     1                     0
# 4                   13000              0       2     1                     0
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         2                          1
# 1                      1                         1                          1
# 2                      1                         1                          1
# 3                      2                         2                          2
# 4                      2                         1                          2
#
# ...

# %%
Master_df['RenalDiseaseIndicator'].value_counts()
# Out:
# 0    448363
# Y    109848
# Name: RenalDiseaseIndicator, dtype: int64

# %%
Master_df['RenalDiseaseIndicator'].replace({'Y':1, '0':0}, inplace=True)

# %%
Master_df['RenalDiseaseIndicator']=Master_df['RenalDiseaseIndicator'].astype(int)

# %%
Master_df.describe(include='O')
# Out:
#        PotentialFraud  IsDead
# count          558211  558211
# unique              2       2
# top                No       0
# freq           345415  554080

# %%
Master_df.dtypes
# Out:
# InscClaimAmtReimbursed               int64
# EncounterType                        int64
# Gender                               int64
# Race                                 int64
# RenalDiseaseIndicator                int64
# ChronicCond_Alzheimer                int64
# ChronicCond_Heartfailure             int64
# ChronicCond_KidneyDisease            int64
# ChronicCond_Cancer                   int64
# ChronicCond_ObstrPulmonary           int64
# ChronicCond_Depression               int64
# ChronicCond_Diabetes                 int64
# ChronicCond_IschemicHeart            int64
# ChronicCond_Osteoporasis             int64
# ChronicCond_rheumatoidarthritis      int64
# ChronicCond_stroke                   int64
# IPAnnualReimbursementAmt             int64
# IPAnnualDeductibleAmt                int64
# OPAnnualReimbursementAmt             int64
# OPAnnualDeductibleAmt                int64
# age                                float64
# Age1                               float64
# ...

# %%
Master_df['IsDead'] = Master_df['IsDead'].astype(float)

# %%
Master_df['PotentialFraud'].replace({'Yes':1, 'No':0}, inplace=True)

# %%
Master_df.dtypes
# Out:
# InscClaimAmtReimbursed               int64
# EncounterType                        int64
# Gender                               int64
# Race                                 int64
# RenalDiseaseIndicator                int64
# ChronicCond_Alzheimer                int64
# ChronicCond_Heartfailure             int64
# ChronicCond_KidneyDisease            int64
# ChronicCond_Cancer                   int64
# ChronicCond_ObstrPulmonary           int64
# ChronicCond_Depression               int64
# ChronicCond_Diabetes                 int64
# ChronicCond_IschemicHeart            int64
# ChronicCond_Osteoporasis             int64
# ChronicCond_rheumatoidarthritis      int64
# ChronicCond_stroke                   int64
# IPAnnualReimbursementAmt             int64
# IPAnnualDeductibleAmt                int64
# OPAnnualReimbursementAmt             int64
# OPAnnualDeductibleAmt                int64
# age                                float64
# Age1                               float64
# ...

# %%
#X and Y dataset

# %%
X = Master_df.drop('PotentialFraud', axis=1)
y = Master_df['PotentialFraud']

# %%
X.drop('Age1', axis=1, inplace=True)

# %%
X.rename(columns={'age':'Age'}, inplace=True)

# %%
num_col= ['InscClaimAmtReimbursed',
       'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
       'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'Age',
       'DaysAdmitted', 'TotalDiagnosis', 'TotalProcedure']

# %%
# X.rename(columns={'daysAdmitted':'DaysAdmitted'}, inplace=True)

# %%
numerical_columns= X.loc[:,num_col]
numerical_columns.describe()
# Out:
#        InscClaimAmtReimbursed  IPAnnualReimbursementAmt  \
# count           558211.000000             558211.000000
# mean               997.012133               5227.971466
# std               3821.534891              11786.274732
# min                  0.000000              -8000.000000
# 25%                 40.000000                  0.000000
# 50%                 80.000000                  0.000000
# 75%                300.000000               6000.000000
# max             125000.000000             161470.000000
#
#        IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  \
# count          558211.000000             558211.000000          558211.000000
# mean              568.756807               2278.225348             649.698745
# std              1179.172616               3881.846386            1002.020811
# min                 0.000000                -70.000000               0.000000
# ...

# %%
cat_col= ['EncounterType', 'Gender', 'Race',
       'RenalDiseaseIndicator', 'ChronicCond_Alzheimer',
       'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
       'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
       'ChronicCond_Depression', 'ChronicCond_Diabetes',
       'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
       'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke','IsDead']

# %%
X_cat = X.loc[:,cat_col]
X_cat
# Out:
#         EncounterType  Gender  Race  RenalDiseaseIndicator  \
# 0                   0       1     1                      0
# 1                   1       1     1                      0
# 2                   0       2     1                      0
# 3                   0       1     1                      0
# 4                   0       2     1                      0
# ...               ...     ...   ...                    ...
# 558206              1       2     1                      0
# 558207              1       1     2                      0
# 558208              1       2     1                      1
# 558209              1       2     1                      0
# 558210              1       2     1                      0
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         1
# 2                           1                         1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_num=scaler.fit_transform(X[num_col])

# %%
x_num
# Out:
# array([[ 6.54266178,  2.61083818,  2.23482594, ...,  2.8326457 ,
#          2.44631775, -0.19091015],
#        [-0.24780959,  1.59270387,  1.32910532, ..., -0.21006383,
#          2.44631775, -0.19091015],
#        [ 4.7109354 ,  1.16848124,  0.4233847 , ...,  5.44068243,
#          2.44631775,  6.93834751],
#        ...,
#        [ 0.28862457, -0.44356476, -0.48233593, ..., -0.21006383,
#         -0.41291261, -0.19091015],
#        [-0.25827659, -0.44356476, -0.48233593, ..., -0.21006383,
#         -0.82137409, -0.19091015],
#        [-0.24519283, -0.44356476, -0.48233593, ..., -0.21006383,
#          0.40401035, -0.19091015]])

# %%
X_num = pd.DataFrame(x_num, columns=['InscClaimAmtReimbursed','IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt','OPAnnualReimbursementAmt', 
                                     'OPAnnualDeductibleAmt', 'Age','DaysAdmitted', 'TotalDiagnosis', 'TotalProcedure'])

# %%
X_num
# Out:
#         InscClaimAmtReimbursed  IPAnnualReimbursementAmt  \
# 0                     6.542662                  2.610838
# 1                    -0.247810                  1.592704
# 2                     4.710935                  1.168481
# 3                     4.187585                  0.998792
# 4                     3.140884                  1.847237
# ...                        ...                       ...
# 558206               -0.130056                 -0.443565
# 558207                0.602635                 -0.443565
# 558208                0.288625                 -0.443565
# 558209               -0.258277                 -0.443565
# 558210               -0.245193                 -0.443565
#
#         IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                    2.234826                 -0.571436
# 1                    1.329105                 -0.470968
# 2                    0.423385                 -0.561132
# ...

# %%
X_cat
# Out:
#         EncounterType  Gender  Race  RenalDiseaseIndicator  \
# 0                   0       1     1                      0
# 1                   1       1     1                      0
# 2                   0       2     1                      0
# 3                   0       1     1                      0
# 4                   0       2     1                      0
# ...               ...     ...   ...                    ...
# 558206              1       2     1                      0
# 558207              1       1     2                      0
# 558208              1       2     1                      1
# 558209              1       2     1                      0
# 558210              1       2     1                      0
#
#         ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                           1                         2
# 1                           1                         1
# 2                           1                         1
# ...

# %%
#dataframe with both numerical and categorical columns

# %%
x= pd.concat([X_num, X_cat], axis=1)
x
# Out:
#         InscClaimAmtReimbursed  IPAnnualReimbursementAmt  \
# 0                     6.542662                  2.610838
# 1                    -0.247810                  1.592704
# 2                     4.710935                  1.168481
# 3                     4.187585                  0.998792
# 4                     3.140884                  1.847237
# ...                        ...                       ...
# 558206               -0.130056                 -0.443565
# 558207                0.602635                 -0.443565
# 558208                0.288625                 -0.443565
# 558209               -0.258277                 -0.443565
# 558210               -0.245193                 -0.443565
#
#         IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                    2.234826                 -0.571436
# 1                    1.329105                 -0.470968
# 2                    0.423385                 -0.561132
# ...

# %%
x.columns
# Out:
# Index(['InscClaimAmtReimbursed', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'DaysAdmitted', 'TotalDiagnosis',
#        'TotalProcedure', 'EncounterType', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke', 'IsDead'],
#       dtype='object')

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 558206    0
# 558207    0
# 558208    0
# 558209    0
# 558210    0
# Name: PotentialFraud, Length: 558211, dtype: int64

# %%
#train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test= train_test_split(x,y, test_size=0.1, random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(x_train, y_train)
train_pred= lr.predict(x_train)
test_pred= lr.predict(x_test)
print(accuracy_score(y_train,train_pred))
print(accuracy_score(y_test,test_pred))
# Out:
# 0.6299401459824956
# 0.6318297445451614
